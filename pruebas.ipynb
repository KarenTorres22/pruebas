# %%
import pandas

# %%
from funciones import palindromos

# %%
palindromos('oso')
# Out:
# True

# %%
from funciones import reverso

# %%
reverso(345)
# Out:
# 543

# %%
from funciones import es_primo

# %%
es_primo(5)
# Out:
# True

# %%
from funciones import par

# %%
par(4)
# Out:
# True
